# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from zipfile import ZipFile
file_name = "/content/drive/My Drive/CovidDataset.zip"
with ZipFile(file_name,'r') as zip:
  zip.extractall()
  print("Completed")
# Out:
# Completed

# %%
from tensorflow.keras.layers import *
from tensorflow.keras.models import * 
import tensorflow.keras as tf

# %%
#Training model
model = Sequential()   ## creating a blank model
model.add(Conv2D(32,kernel_size=(3,3),activation='relu',input_shape=(224,224,3)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))    ### reduce the overfitting
 
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
 
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
 
model.add(Flatten())    ### input layer
model.add(Dense(64,activation='relu'))    ## hidden layer of ann
model.add(Dropout(0.5))
model.add(Dense(1,activation='sigmoid'))   ## output layer
 
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
#Moulding train images
from tensorflow.keras.preprocessing import image
train_datagen = image.ImageDataGenerator(rescale = 1./255, shear_range = 0.2,zoom_range = 0.2, horizontal_flip = True)
 
test_dataset = image.ImageDataGenerator(rescale=1./255)

# %%
#Reshaping test and validation images 
train_generator = train_datagen.flow_from_directory(
    '/content/CovidDataset/Train',
    target_size = (224,224),
    batch_size = 32,
    class_mode = 'binary')
validation_generator = test_dataset.flow_from_directory(
    '/content/CovidDataset/Val',
    target_size = (224,224),
    batch_size = 32,
    class_mode = 'binary')
# Out:
# Found 224 images belonging to 2 classes.
# Found 60 images belonging to 2 classes.

# %%
#### Train the model
history = model.fit_generator(
    train_generator,
    steps_per_epoch=7,
    epochs = 20,
    validation_data = validation_generator,
    validation_steps=1
)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/20
# 7/7 [==============================] - 15s 1s/step - loss: 0.7448 - accuracy: 0.5901 - val_loss: 0.6889 - val_accuracy: 0.9375
# Epoch 2/20
# 7/7 [==============================] - 9s 1s/step - loss: 0.6733 - accuracy: 0.6667 - val_loss: 0.6554 - val_accuracy: 0.8438
# Epoch 3/20
# 7/7 [==============================] - 9s 1s/step - loss: 0.5863 - accuracy: 0.7576 - val_loss: 0.4872 - val_accuracy: 0.9062
# Epoch 4/20
# 7/7 [==============================] - 9s 1s/step - loss: 0.4239 - accuracy: 0.8035 - val_loss: 0.2187 - val_accuracy: 0.9688
# Epoch 5/20
# 7/7 [==============================] - 9s 1s/step - loss: 0.2685 - accuracy: 0.8874 - val_loss: 0.2912 - val_accuracy: 0.9375
# Epoch 6/20
# 7/7 [==============================] - 9s 1s/step - loss: 0.2061 - accuracy: 0.9213 - val_loss: 0.0949 - val_accuracy: 0.9688
# Epoch 7/20
# 7/7 [==============================] - 9s 1s/step - loss: 0.1700 - accuracy: 0.9317 - val_loss: 0.1522 - val_accuracy: 0.9688
# Epoch 8/20
# 7/7 [==============================] - 9s 1s/step - loss: 0.1278 - accuracy: 0.9663 - val_loss: 0.0652 - val_accuracy: 1.0000
# Epoch 9/20
# 7/7 [==============================] - 9s 1s/step - loss: 0.1829 - accuracy: 0.9340 - val_loss: 0.1040 - val_accuracy: 1.0000
# Epoch 10/20
# 7/7 [==============================] - 9s 1s/step - loss: 0.1292 - accuracy: 0.9481 - val_loss: 0.0395 - val_accuracy: 1.0000
# Epoch 11/20
# 7/7 [==============================] - 9s 1s/step - loss: 0.0856 - accuracy: 0.9757 - val_loss: 0.0318 - val_accuracy: 1.0000
# Epoch 12/20
# 7/7 [==============================] - 9s 1s/step - loss: 0.1566 - accuracy: 0.9449 - val_loss: 0.0669 - val_accuracy: 0.9688
# Epoch 13/20
# 7/7 [==============================] - 9s 1s/step - loss: 0.1314 - accuracy: 0.9675 - val_loss: 0.0779 - val_accuracy: 0.9688
# Epoch 14/20
# 7/7 [==============================] - 9s 1s/step - loss: 0.0967 - accuracy: 0.9788 - val_loss: 0.0181 - val_accuracy: 1.0000
# Epoch 15/20
# 7/7 [==============================] - 9s 1s/step - loss: 0.2022 - accuracy: 0.9209 - val_loss: 0.0986 - val_accuracy: 0.9375
# Epoch 16/20
# 7/7 [==============================] - 9s 1s/step - loss: 0.2003 - accuracy: 0.9235 - val_loss: 0.1569 - val_accuracy: 0.9688
# Epoch 17/20
# 7/7 [==============================] - 8s 1s/step - loss: 0.2069 - accuracy: 0.9342 - val_loss: 0.1519 - val_accuracy: 0.9688
# Epoch 18/20
# 7/7 [==============================] - 9s 1s/step - loss: 0.1495 - accuracy: 0.9553 - val_loss: 0.0708 - val_accuracy: 0.9688
# Epoch 19/20
# 7/7 [==============================] - 8s 1s/step - loss: 0.0936 - accuracy: 0.9741 - val_loss: 0.0432 - val_accuracy: 1.0000
# Epoch 20/20
# 7/7 [==============================] - 8s 1s/step - loss: 0.0756 - accuracy: 0.9763 - val_loss: 0.0347 - val_accuracy: 0.9688

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
img = image.load_img('/content/covid.jpg',target_size=(224,224))
img = image.img_to_array(img)
img = np.expand_dims(img,axis=0)   ### flattening
ypred = model.predict(img)
if ypred[0][0] == 1:
  print("Covid Negative")
else:
  print("Covid Positive")
# Out:
# Covid Positive

# %%
ypred[0][0]
# Out:
# 0.0

# %%
#### save the model
model.save("covid_model.h5")

# %%
import tensorflow.keras as tf
mymodel = tf.models.load_model("/content/covid_model.h5")

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
img = image.load_img('/content/covid.jpg',target_size=(224,224))
img = image.img_to_array(img)
img = np.expand_dims(img,axis=0)   ### flattening
ypred = mymodel.predict(img)
if ypred[0][0] == 1:
  print("Covid Negative")
else:
  print("Covid Positive")
# Out:
# Covid Positive
